# %% [markdown]
# ### 1. Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 2. Masuk ke Project

# %%
import os

PROJECT = "/content/drive/MyDrive/smart-hospital-ai"

os.chdir(PROJECT)

print(os.getcwd())
# Out:
# /content/drive/MyDrive/smart-hospital-ai

# %% [markdown]
# ## 3. Install Requirements

# %%
# !pip install -q -r requirements.txt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 70.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 59.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 70.8 MB/s eta 0:00:00

# %% [markdown]
# ## 4. Set API KEY

# %%
from google.colab import userdata

os.environ["GROQ_API_KEY"] = userdata.get("GROQ")

# %% [markdown]
# ## 5. Menjalankan Streamlit

# %%
# !streamlit run app.py \
    --server.address=0.0.0.0 \
    --server.port=8501 \
    --server.headless=true \
    > streamlit.log 2>&1 &

# %% [markdown]
# ## 6. Menjalankan Ngrok

# %%
from google.colab import userdata
from pyngrok import ngrok

ngrok.set_auth_token(userdata.get("NGROK"))

public_url = ngrok.connect(8501)

print(public_url.public_url)
# Out:
# https://treble-glamorous-headboard.ngrok-free.dev
